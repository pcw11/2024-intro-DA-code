# %% [markdown]
# <a href="https://colab.research.google.com/github/pcw11/2024-intro-DA-code/blob/main/w01_intro_DA_for_jupyter_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 01주 코딩 연습
# ## 코랩을 위한 주피터 노트북 기초

# %% [markdown]
# ## 간단한 데이터 시각화 기초

# %%
import numpy as np
np.__version__
# Out:
# '1.26.4'

# %%
# %congfig inlineBackend.figure_format = 'retina'
# Out:
# UsageError: Line magic function `%congfig` not found.

# %%
# !pip install koreanize-matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 47.1 MB/s eta 0:00:00
# ...

# %%
import koreanize_matplotlib

# %%
import matplotlib.pyplot as plt

plt.title('데이터 시각화를 위한 한글 준비와 기본 직선 그래프')
plt.plot([10, 5, 25, 30])
plt.show()

# %%
import matplotlib.pyplot as plt

plt.title('데이터 시각화를 위한 한글 준비와 기본 직선 그래프')
plt.plot([0,1,2,3], [10, 5, 25, 30])
plt.show()

# %% [markdown]
# ### End of code
